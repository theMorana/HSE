# %% [markdown]
# <a href="https://colab.research.google.com/github/theMorana/HSE/blob/main/Homeworks%5CHometask%235_collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Синтаксис

# %% [markdown]
# **Задача 1**
#
# Создайте список mixed_data, содержащий:
#
# - 3 числа (int)
# - 2 строки (str)
# - 1 вложенный список
# - 1 кортеж
# - 1 множество
#
# Добавьте в конец списка число 123
#
# Удалите вторую строку из списка
#
# Вставьте строку "inserted" на позицию 2
#
# Выведите итоговый список

# %%
mixed_data = [
    1,
    "hello",
    3,
    [1, 2],
    42,
    "world",
    0,
    (5, 6),
    {7, 8, 9},
    123
]

mixed_data.append("inserted" )

print(mixed_data)
# Out:
# [1, 'hello', 3, [1, 2], 42, 'world', 0, (5, 6), {8, 9, 7}, 123, 'inserted']

# %% [markdown]
# **Задача 2**
#
# Создайте кортеж user_credentials, содержащий:
#
# - Логин (строка)
#
# - Хэш пароля (строка)
#
# - Уровень доступа (целое число)
#
# Попробуйте изменить уровень доступа (должна возникнуть ошибка)
#
# Напишите комментарий, почему кортеж подходит для хранения таких данных

# %%
user_credentials = ('loginUser', '#657Tgjsu_', 5)
user_credentials[2] = 4
# Получим ошибку, т.к. перезапись элемента, который мы можем достать по индексу - изменение
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-773592836.py in <cell line: 0>()
#       1 user_credentials = ('loginUser', '#657Tgjsu_', 5)
# ----> 2 user_credentials[2] = 4
#       3 # Получим ошибку, т.к. перезапись элемента, который мы можем достать по индексу - изменение
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Задача 3**
#
# Дано:

# %%
tags1 = {"python", "ml", "data"}
tags2 = {"ml", "nlp", "deeplearning"}

# %% [markdown]
# Найдите:
#
# - Общие теги (пересечение)
#
# - Все уникальные теги (объединение)
#
# - Теги, которые есть в tags1, но нет в tags2

# %%
general = tags1 & tags2
unique = tags1 | tags2
only_one = tags1 - tags2

print(f"Общие: {general} \nУникальные: {unique} \nТолько в первом множестве: {only_one}")
# Out:
# Общие: {'ml'}
# Уникальные: {'nlp', 'python', 'data', 'ml', 'deeplearning'}
# Только в первом множестве: {'python', 'data'}

# %% [markdown]
# ### Фильтрация и обработка текстовых данных

# %% [markdown]
# 1. Установите nltk и загрузите стоп-слова для русского и английского языков
#
# *Уже выполнено: просто запустите эту ячейку*

# %%
import nltk
import string
from nltk.corpus import stopwords

# Установка nltk и загрузка стоп-слов
nltk.download('stopwords')

# Загрузка стоп-слов для русского и английского языков
stopwords_english = stopwords.words('english')
stopwords_russian = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# 2. Конвертируйте списки слов на русском и английском, приведите их к виду множства `set`
#
# *Это стандартная операция: работа со стоп-словами всегда начинается с фильтрации, удаления дубликатов*

# %%
stopwords_english = set(stopwords_english)
stopwords_russian = set(stopwords_russian)
count = 0
english_list= []
russian_list = []
for word in stopwords_english:
    english_list.append(word)
    count += 1
    if count == 10:
        break
print("Английские стоп-слова (первые 10):", english_list)
count = 0
for word in stopwords_english:
    russian_list.append(word)
    count += 1
    if count == 10:
        break
print("Русские стоп-слова (первые 10):", russian_list)
# Out:
# Английские стоп-слова (первые 10): ['myself', 'which', 'both', "she's", 'm', 'up', "they've", 'haven', 'those', 'down']
# Русские стоп-слова (первые 10): ['myself', 'which', 'both', "she's", 'm', 'up', "they've", 'haven', 'those', 'down']

# %% [markdown]
# 3. Выведите на экран первые 10 стоп-слов из двух списков
#
# *Подумайте, как это сделать, ведь `set` нельзя индексировать, а созданный список слов нельзя перезаписывать*

# %%
### ваш код здесь ###
# Out:
# Английские стоп-слова (первые 10): ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
# Русские стоп-слова (первые 10): ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со']

# %% [markdown]
# 4. Дан текст

# %%
# Исходный текст
text = """
This is a sample text for processing. It contains some stopwords and important words.
Этот текст содержит как английские, так и русские слова, включая стоп-слова.
"""

# %% [markdown]
# Допишите функцию в указанном плейсхолдере
#
# Функция:
#
# - удаляет знаки препинания
# - разбивает текст на слова
# - приводит текст к нижнему регистру

# %%
# Токенизация текста на слова
import re
def tokenize_text(text):
    # Убираем знаки препинания и разбиваем на слова
    text = text.lower()
    words = re.sub(r'[^а-яёa-z0-9.,!? -]', ' ', text)
    words = text.split()
    return words

# %% [markdown]
# Применим нашу функцию к тексту

# %%
# Токенизируем текст
words = tokenize_text(text)
count = len(words)
print("Все слова после токенизации:", words)
print("Всего слов:", count)
# Out:
# Все слова после токенизации: ['this', 'is', 'a', 'sample', 'text', 'for', 'processing.', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words.', 'этот', 'текст', 'содержит', 'как', 'английские,', 'так', 'и', 'русские', 'слова,', 'включая', 'стоп-слова.']
# Всего слов: 25

# %% [markdown]
# Выведите на экран список токенов и общее количество слов

# %%
### ваш код здесь ###
# Out:
# Все слова после токенизации: ['this', 'is', 'a', 'sample', 'text', 'for', 'processing', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words', 'этот', 'текст', 'содержит', 'как', 'английские', 'так', 'и', 'русские', 'слова', 'включая', 'стопслова']
# Всего слов: 25

# %% [markdown]
# 5. Произведите фильтрацию стоп-слов для двух языков
#
# - Создайте пустой список
# - Запустите цикл for (`for word in words`, для каждого слова в списке слов)
# - Если слова нет в списке стоп-слов
# - Сделайте `append` в созданный список
#
# *Допишите функцию*

# %%
# Фильтрация стоп-слов для обоих языков

def filter_stopwords(words, stopwords_set):
    filtered_words = []
    for word in words:
        if word not in stopwords_set:
            filtered_words.append(word)
    return filtered_words

# %% [markdown]
# 6. Примените операции со множествами

# %%
# Объедините стоп-слова обоих языков в общее множество
all_stopwords  = stopwords_english  | stopwords_russian
print(all_stopwords)
# Out:
# {'была', 'both', 'up', 'm', "they've", 'haven', 'down', 'зачем', 'через', 'здесь', 'from', 'most', 'она', 'может', 'тогда', 'там', 'сейчас', 'эти', 'но', 'until', 'этого', 'this', 'его', 'all', "needn't", 'but', 'когда', 'по', 'почти', "we've", 'разве', 'does', 'того', 'had', 'тут', 'under', 'during', 'один', 'же', 'didn', 'о', "aren't", 'ma', 'weren', "you'll", 'ourselves', "it's", "you've", 'тебя', 'its', 'ней', 'for', 'надо', 'какой', 'nor', 'только', 'above', 'мы', 'o', 'am', 'be', 'этом', 'before', 'don', 'each', 'when', "couldn't", 'his', 't', 'now', 'why', 'теперь', 'off', 'too', "don't", 'конечно', 'об', "i've", "mustn't", 'быть', 'во', 'так', 'было', "doesn't", 'тем', 'he', 'лучше', 'him', 'на', 'won', 'вдруг', "shan't", 'yours', 'будто', 'same', 'being', 'did', 'more', 'there', 'опять', 'и', 'от', 'или', 'потому', 'such', 'ну', 'just', 'тоже', 'your', 'будет', 'ничего', 'после', 'бы', 'а', 'у', 'll', 'it', 'они', 'my', 'при', 'her', 'нет', 'под', 'нее', 'меня', 'совсем', 'a
# ...

# %% [markdown]
# 7. Применим нашу функцию для фильтрации данных
#
# *В переменной `all_stopwords` должен быть результат объединения множеств из пункта 6*

# %%
# Фильтруем стоп-слова
meaningful_words = filter_stopwords(words, all_stopwords)
print(f"Список: {meaningful_words} \nКол-во: {len(meaningful_words)}")
# Out:
# Список: ['sample', 'text', 'processing.', 'contains', 'stopwords', 'important', 'words.', 'текст', 'содержит', 'английские,', 'русские', 'слова,', 'включая', 'стоп-слова.']
# Кол-во: 14

# %% [markdown]
# Выведите на экран список `meaningful_words`, а также длину этого списка

# %%
### ваш код здесь ###
# Out:
# Слова после фильтрации стоп-слов: ['sample', 'text', 'processing', 'contains', 'stopwords', 'important', 'words', 'текст', 'содержит', 'английские', 'русские', 'слова', 'включая', 'стопслова']
# Количество слов после фильтрации: 14

# %% [markdown]
# 8. Создаем множество уникальных значимых слов
#
# *Конвертируем список `meaningful_words` к виду множества*

# %%
meaningful_words = set (meaningful_words )

# %% [markdown]
# Выведите на экран результат, а также длину полчившегося множества

# %%
print("Уникальные значимые слова:", meaningful_words)
print("Количество уникальных значимых слов:", len(meaningful_words) )
# Out:
# Уникальные значимые слова: {'important', 'текст', 'words.', 'sample', 'содержит', 'английские,', 'contains', 'text', 'processing.', 'включая', 'слова,', 'стоп-слова.', 'русские', 'stopwords'}
# Количество уникальных значимых слов: 14

# %% [markdown]
# 9. Создайте отчет
#
# - выведите исходное количество стоп-слов на английском
# - исходное количество слов на русском
# - общее количество стоп-слов

# %%
print(f"Всего стоп-слов (английские): {len(stopwords_english)}")
print(f"Всего стоп-слов (русские): {len(stopwords_russian)}")
print(f"Всего стоп-слов (объединенные): {len(all_stopwords)}")
# Out:
# Всего стоп-слов (английские): 198
# Всего стоп-слов (русские): 151
# Всего стоп-слов (объединенные): 349

# %% [markdown]
# 10. Проведите анализ результатов: какие стоп-слова были удалены из исходного текста?
#
# - создайте список для сохранения отфильтрованных слов
# - для каждого слова исходного текста (`text`)
# - если данное слово было в списке стоп-слов
# - добавляем его в созданный список
#
# *Выведите на экран отфильтрованные слова (т.е. удаленные)*

# %%
#я решила прописать так, чтобы сразу всё было видно и не пришлось перелистывать пол блокнота)
def defilter_stopwords(words, stopwords_set):
    defiltered_words = []
    for word in words:
        if word in stopwords_set:
            defiltered_words.append(word)
    return defiltered_words

meaningful_words = defilter_stopwords(words, all_stopwords)
all_stopwords  = stopwords_english  | stopwords_russian
print(f"Отфильтрованные стоп-слова: {meaningful_words}")

#Отфильтрованные стоп-слова: ['this', 'is', 'a', 'for', 'it', 'some', 'and', 'этот', 'как', 'так', 'и']
# Out:
# Отфильтрованные стоп-слова: ['this', 'is', 'a', 'for', 'it', 'some', 'and', 'этот', 'как', 'так', 'и']
